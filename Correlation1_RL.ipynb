# %% [markdown]
# <a href="https://colab.research.google.com/github/21csu062/Nikhil_Reinforcement-Learning/blob/main/Correlation1_RL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np


np.random.seed(1)


x=np.random.randint(0,50,1000)
x
# Out:
# array([37, 43, 12,  8,  9, 11,  5, 15,  0, 16,  1, 12,  7, 45,  6, 25, 20,
#        37, 18, 20, 11, 42, 28, 29, 14,  4, 23, 23, 41, 49, 30, 32, 22, 13,
#        41,  9,  7, 22,  1,  0, 17,  8, 24, 13, 47, 42,  8, 30,  7,  3,  6,
#        21, 49,  3,  4, 24, 49, 43, 12, 26, 16, 45, 41, 18, 15,  0,  4, 25,
#        47, 34, 23,  7, 26, 25, 40, 22,  9,  3, 39, 23, 36, 27, 37, 19, 38,
#         8, 32, 34, 10, 23, 15, 47, 23, 25,  7, 28, 10, 46, 32, 24, 23,  1,
#        49, 13,  3,  0, 13,  6, 21,  6,  2, 12, 27, 21, 11,  7, 13,  8, 11,
#        12, 43, 20, 30, 36, 39,  7, 45,  4, 48, 18, 32, 13, 10, 23, 17,  7,
#        24, 10, 28, 20, 32, 12,  1, 30, 41, 24, 18, 33,  2, 44, 28, 39, 34,
#        10, 32, 41, 18, 22,  6,  2,  7, 39, 48, 15,  5, 17, 42, 20, 48, 22,
#        37, 13, 49, 33, 20, 10, 32, 25, 21, 39, 32, 19, 25, 49, 14, 13, 20,
#        43,  6, 13, 15, 24,  9,  2,  7,  5, 36, 37, 21, 40, 13, 27, 49, 49,
# ...

# %%
y=x+np.random.normal(0,10,1000)
y
# Out:
# array([ 20.91943595,  50.63680457,  26.1899858 ,   4.2567297 ,
#          4.76682859,  -1.41868013,   0.13974066,  12.68595762,
#         -2.4644001 ,  23.67966704,  -5.26864647,  44.705657  ,
#          3.929594  ,  41.15251149,   6.15189145,  16.87380256,
#         12.12197948,  23.85785176,  19.98609381,  17.29294368,
#         13.81247183,  29.45979256,  29.23125049,  15.30400214,
#          7.32581754,   8.57716492,   8.37879784,  25.63585484,
#         49.04095427,  58.34967036,  32.56479127,  29.70811918,
#          1.18361352,  25.66966811,  49.05104488,  18.60306431,
#         11.34949454,  28.80212162,  19.68884019,   1.50705284,
#         11.31341917,  20.74937886,  31.50733465,  21.09738523,
#         32.61895129,  58.59052608,  11.11072572,  32.15714494,
#          2.25252158,  -0.26341235,  -1.10116519,  10.9632299 ,
#         50.14247927,  13.13755659,  -3.20034693,  19.75343555,
#         57.20068833,  27.88677104,   7.24892855,   6.40492564,
# ...

# %%
np.corrcoef(x,y)
# Out:
# array([[1.        , 0.81543901],
#        [0.81543901, 1.        ]])

# %%
from io import IncrementalNewlineDecoder
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
matplotlib.style.use('ggplot')

plt.scatter(x,y)
plt.show()

# %%
y=x-np.random.normal(0,10,1000)
y
# Out:
# array([ 5.04723141e+01,  4.56237947e+01,  1.11680144e+01,  1.43453284e+01,
#         1.30248275e+01,  1.06593881e+00,  6.32637381e+00,  2.25838718e+01,
#         1.38452940e+01, -2.93289714e+00, -2.96551937e+00,  4.80935321e+00,
#        -1.26788592e+01,  4.81991765e+01,  5.46873617e-01,  1.94202343e+01,
#         2.87138898e+01,  4.41692826e+01,  6.60448617e+00,  2.23223234e+01,
#         3.78460397e+00,  4.28222646e+01,  1.56007504e+01,  4.42997124e+01,
#         1.44853845e+01,  1.00535269e+01,  1.90112311e+01,  4.34818825e+01,
#         4.74971588e+01,  5.27023948e+01,  1.77029897e+01,  2.05892466e+01,
#         1.68475710e+01,  8.29141022e+00,  5.25689618e+01,  3.25429398e+00,
#         1.23500533e+01,  3.76608842e+01,  1.55751055e+01, -2.70022471e+01,
#         4.70201137e+00,  9.17754544e+00,  2.19010948e+01,  1.05475926e+01,
#         4.51058278e+01,  3.19220756e+01,  7.00970449e+00,  2.56869331e+01,
# ...

# %%
np.corrcoef(x,y)
# Out:
# array([[1.        , 0.82551158],
#        [0.82551158, 1.        ]])

# %%
plt.scatter(x,y)
plt.show()

# %%
y=100-x+np.random.normal(0,5,1000)
y
# Out:
# array([ 58.32994188,  55.5908905 ,  80.19578227,  92.98921793,
#         94.92492887,  94.7191019 ,  91.54315894,  88.5620399 ,
#         99.88499235,  81.50472801, 102.26459828,  77.66413056,
#         98.52515654,  57.96806715,  95.02029247,  80.84869078,
#         73.70127546,  64.99983914,  79.22579429,  77.80501927,
#         84.66850575,  56.63611044,  83.27902457,  71.91817679,
#         84.28755632,  91.84772203,  77.23167577,  73.13604826,
#         65.00075607,  58.81012835,  67.13703729,  71.39819258,
#         70.43905324,  91.53192628,  57.68582198,  88.22483041,
#         90.45022732,  79.45335842,  95.95807434, 105.89003429,
#         82.95169022,  96.41444779,  74.40397952,  89.12840299,
#         45.99854469,  51.01723007,  90.57896449,  66.61220317,
#         90.83035518, 107.35713414,  92.20576896,  81.95415205,
#         44.16496406,  91.47626681,  89.3184401 ,  77.10876163,
#         57.31141529,  48.06149051,  88.19709166,  69.20616317,
# ...

# %%
np.corrcoef(x,y)
# Out:
# array([[ 1.        , -0.94110977],
#        [-0.94110977,  1.        ]])

# %%
plt.scatter(x,y)

# %%
y=np.random.randint(0,25,1000)

z=y-np.random.normal(0,20,1000)
z
# Out:
# array([-2.42323528e+01,  2.21635060e+01,  1.94432174e+01,  1.45857225e+00,
#         5.11332517e+00, -9.17137553e+00,  1.67010122e+01,  1.62644856e+01,
#        -3.49107792e+01,  3.55336151e+01, -3.07990626e+00,  2.79436745e+01,
#         3.19694884e+00,  2.51096699e+01,  1.98073809e+01,  2.20090833e+01,
#        -2.11991663e+01,  3.28590883e+01, -1.12812234e+01,  3.51605865e+01,
#         2.29316901e+01,  3.81180352e+01, -2.80880423e+01, -2.82053495e+01,
#         6.30089006e+00,  2.94194240e+01,  1.72067736e+00,  2.77670811e+01,
#         2.82899019e+00, -4.44322216e+01,  2.53876344e+01,  2.86022747e+01,
#        -6.31756562e+00,  4.92985076e+01, -1.17160501e+01, -2.70452332e+01,
#         3.41738182e+01,  2.95918895e+01,  6.05540596e+01,  1.72667592e+01,
#         1.52991743e+01,  1.62352035e+01, -1.51359620e+00,  9.38591582e+00,
#         4.45661264e+00, -1.45816978e+01,  3.60697230e+00,  2.64040525e+01,
# ...

# %%
np.corrcoef(y,z)
# Out:
# array([[1.        , 0.36400462],
#        [0.36400462, 1.        ]])

# %%
plt.scatter(y,z)

# %%
x=np.random.randint(0,50,1000)
y=np.random.randint(0,50,1000)

np.corrcoef(x,y)
# Out:
# array([[ 1.        , -0.04254906],
#        [-0.04254906,  1.        ]])

# %%
plt.scatter(x,y)

# %%
import pandas as pd

df = pd.DataFrame({'a':np.random.randint(0,50,1000)})
df['b']=df['a']+np.random.normal(0,10,1000)
df['c']=100-df['a']+np.random.normal(0,5,1000)
df['d']=np.random.randint(0,50,1000)

df.corr()
# Out:
#           a         b         c         d
# a  1.000000  0.812267 -0.940508  0.042150
# b  0.812267  1.000000 -0.769643  0.050230
# c -0.940508 -0.769643  1.000000 -0.031643
# d  0.042150  0.050230 -0.031643  1.000000

# %%
pd.plotting.scatter_matrix(df,figsize=(6,6))
plt.show()

# %%
plt.matshow(df.corr())
plt.xticks(range(len(df.columns)),df.columns)
plt.yticks(range(len(df.columns)),df.columns)
plt.colorbar()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
